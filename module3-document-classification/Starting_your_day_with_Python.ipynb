# %% [markdown]
# ### Rise and shine, time to check the news. Write a Python program to get the top news stories from Google. Bonus points if you can do additional news sources.

# %%
import bs4
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen

news_url="https://news.google.com/news/rss"
Client=urlopen(news_url)
xml_page=Client.read()
Client.close()

soup_page=soup(xml_page,"xml")
news_list=soup_page.findAll("item")
# Print news title, url and publish date
for news in news_list:
  print(news.title.text)
  print(news.link.text)
  print(news.pubDate.text)
  print("-"*60)
# Out:
# 'I was on the phone call': Pompeo acknowledges he was listening to Trump's phone call with Ukraine president - USA TODAY
# https://www.usatoday.com/story/news/politics/2019/10/02/pompeo-admits-he-trumps-phone-call-ukraine-zelensky/3838914002/
# Wed, 02 Oct 2019 11:57:00 GMT
# ------------------------------------------------------------
# A WWII-era B-17 bomber has crashed at an airport near Hartford, Connecticut - CNN
# https://www.cnn.com/2019/10/02/us/connecticut-plane-crash-trnd/index.html
# Wed, 02 Oct 2019 15:11:00 GMT
# ------------------------------------------------------------
# North Korea May Have Taken Step Toward Submarine-Launched Ballistic Missile - NPR
# https://www.npr.org/2019/10/02/766324902/north-korea-missile-test-may-have-been-launched-from-a-submarine
# Wed, 02 Oct 2019 09:05:00 GMT
# ------------------------------------------------------------
# Live updates: House Democrats to subpoena White House for documents in its impeachment inquiry focused on Ukraine - The Washington Post
# https://www.washingtonpost.com/politics/trump-impeachment-whistleblower/2019/10/02/80df829a-e494-11e9-b403-f738899982d2_story.html
# Wed, 02 Oct 2019 14:54:00 GMT
# ------------------------------------------------------------
# Boris Johnson presses U.K. elections as Brexit endgame nears - NBC News
# https://www.nbcnews.com/news/world/boris-johnson-presses-u-k-elections-brexit-endgame-nears-n1061076
# Wed, 02 Oct 2019 12:27:00 GMT
# ------------------------------------------------------------
# House official says Trump's former Ukraine envoy will testify this week | TheHill - The Hill
# https://thehill.com/homenews/house/463913-house-official-says-trumps-former-ukraine-envoy-will-testify-this-week
# Tue, 01 Oct 2019 21:27:05 GMT
# ------------------------------------------------------------
# Bernie Sanders hospitalized with chest pain, campaign events canceled - ABC News
# https://abcnews.go.com/Politics/bernie-sanders-78-canceled-events-notice-hospitalized/story?id=66003850
# Wed, 02 Oct 2019 15:08:00 GMT
# ------------------------------------------------------------
# Warren passes Biden to lead 2020 Democrats by 4 points in weekly national poll | TheHill - The Hill
# https://thehill.com/homenews/campaign/463997-warren-passes-biden-to-lead-field-by-4-points-nationally-poll
# Wed, 02 Oct 2019 14:30:28 GMT
# ------------------------------------------------------------
# Robert Jeffress Goes All In on “Civil War” - Slate
# https://slate.com/news-and-politics/2019/10/who-is-robert-jeffress-civil-war-trump-impeachment.html
# Tue, 01 Oct 2019 23:34:00 GMT
# ------------------------------------------------------------
# Wed, 02 Oct 2019 10:45:00 GMT
# ------------------------------------------------------------
# NASA is hearing 'peculiar sounds' on Mars - Fox News
# https://www.foxnews.com/science/nasa-peculiar-sounds-on-mars
# Wed, 02 Oct 2019 14:19:17 GMT
# ------------------------------------------------------------
# Oumuamua news: Do intergalactic nomads really ‘seed the universe’? - Express.co.uk
# https://www.express.co.uk/news/science/1180261/oumuamua-news-new-scientist-live-space-aliens-anomaly-nasa-esa-latest
# Wed, 02 Oct 2019 06:00:00 GMT
# ------------------------------------------------------------
# Musk’s Amped-Up Timetable for Mars Spaceship Contrasts With Delays for NASA Capsules - The Wall Street Journal
# https://www.wsj.com/articles/musks-amped-up-timetable-for-mars-spaceship-contrasts-with-delays-for-nasa-capsules-11569807210
# Mon, 30 Sep 2019 15:58:00 GMT
# ------------------------------------------------------------
# 1st vaping-related death reported in New Jersey: Officials - WABC-TV
# https://abc7ny.com/health/1st-vaping-related-death-reported-in-new-jersey-officials/5582530/
# Wed, 02 Oct 2019 12:50:07 GMT
# ------------------------------------------------------------
# Here's The Real Truth About That Confusing Red Meat Study - ScienceAlert
# https://www.sciencealert.com/here-s-the-real-truth-about-that-confusing-red-meat-study
# Wed, 02 Oct 2019 02:41:15 GMT
# ------------------------------------------------------------
# 3 deaths, 1 hospitalization, but health officials say no need to panic over EEE - WFSB
# https://www.wfsb.com/news/deaths-hospitalization-but-health-officials-say-no-need-to-panic/article_6d6f9e54-e4fb-11e9-a90e-a77c33812167.html
# Wed, 02 Oct 2019 11:13:00 GMT
# ------------------------------------------------------------
# 16 Indianapolis students mistakenly injected with insulin - WKYT
# https://www.wkyt.com/content/news/16-Indianapolis-students-mistakenly-injected-with-insulin-561859491.html
# Tue, 01 Oct 2019 11:30:58 GMT
# ------------------------------------------------------------

# %% [markdown]
# ### What is the weather like today? Write a Python program to find the live weather report (temperature, wind speed, description and weather) of a given city. **Hint** [one easy source](https://openweathermap.org/api)

# %%
import requests
from pprint import pprint
def weather_data(query):
    res=requests.get('http://api.openweathermap.org/data/2.5/weather?'+query+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric');
    return res.json();

def print_weather(result,city):
    print("{}'s temperature: {}°C ".format(city,result['main']['temp']))
    print("Wind speed: {} m/s".format(result['wind']['speed']))
    print("Description: {}".format(result['weather'][0]['description']))
    print("Weather: {}".format(result['weather'][0]['main']))
def main():
    city=input('Enter the city:')
    print()
    try:
        query='q='+city;
        w_data=weather_data(query);
        print_weather(w_data, city)
        print()
    except:
        print('City name not found...')
if __name__=='__main__':
    main()
# Out:
# Enter the city:Los Angeles
#
# Los Angeles's temperature: 16.12°C
# Wind speed: 1.97 m/s
# Description: clear sky
# Weather: Clear
